# %%
import pandas as pd
import numpy as np
import re
#import matplotlib.pyplot as plt
import datetime

# %%
ratings_rb = pd.read_csv('ratings_rb.csv', keep_default_na=False)

# %%
beer_rb = pd.read_csv('./RateBeer/beers.csv')

# %%
brew_rb = pd.read_csv('./RateBeer/breweries.csv')

# %%
users = pd.read_csv('users.csv')

# %%
breweries = pd.read_csv('brew.csv')

# %% [markdown]
# ### Length of review

# %%
# Regex to replace all non alphabet/space characters with a space (This version tries to keep diacritic and accented characters)
# This is not a perfect 100% encompassing solution. Users sometimes have typos or other irregularities in their text e.g. 'bottlePour' being counted as 1 word.
# Phrases such as 0.33ml might also be separated into two mistakenly such as '0' and '33ml'
def remove_punct(review):
    return re.sub('[^\w\s]', ' ', review)
    
def count_words(review):
    return len(review.split())

# %%
rb_raw_text = ratings_rb['text'].apply(remove_punct)

# %%
review_len_rb = rb_raw_text.apply(count_words)

# %%
ratings_rb['text_length'] = review_len_rb

# %% [markdown]
# ### Relative Time of review

# %%
first_review_time_rb = ratings_rb.groupby('beer_name')['date'].min()
first_review_time_rb
# Out:
# beer_name
# #5 Belgian Golden Tripel        1500199200
# #Freedom The Berry Amendment    1382871600
# #Freedom Unalienable Rights     1382871600
# #Poekhali Spas IPA              1485601200
# #Poekhali!! Belka               1468231200
#                                    ...
# Żywiec Szampańskie              1475488800
# Žemaičių Alus                   1215511200
# ’t Goeye Goet Dubbel            1222164000
# 北京赤 红云生 Buzz                    1494842400
# 爱啤                              1493805600
# Name: date, Length: 396448, dtype: int64

# %%
def relative_time_rb(time, beer_name):
    return time - first_review_time_rb.loc[beer_name]

# %%
ratings_rb['relative_time'] = ratings_rb.apply(lambda x: relative_time_rb(x['date'], x['beer_name']), axis=1)

# %% [markdown]
# ### Time of writing review

# %%
ratings_rb['review_time'] = ratings_rb['date'].apply(datetime.datetime.fromtimestamp)

# %% [markdown]
# ### Country of beer and country of user

# %%
user_df = users[['user_id', 'location']].set_index(keys='user_id')

# %%
ratings_rb['user_id'] = ratings_rb['user_id'].apply(str)

# %%
users['user_id']
# Out:
# 0                nmann08.184925
# 1            stjamesgate.163714
# 2                 mdagnew.19527
# 3         helloloser12345.10867
# 4               cypressbob.3708
#                   ...
# 223873                   134893
# 223874                   327816
# 223875                   183139
# 223876                    82020
# 223877                    48123
# Name: user_id, Length: 223878, dtype: object

# %%
ratings_rb = ratings_rb.merge(how='left' ,right=user_df, on='user_id')

# %%
ratings_rb
# Out:
#                    beer_name  beer_id        date     user_name user_id  \
# 0          33 Export (Gabon)   410549  1461664800       Manslow  175852
# 1        Castel Beer (Gabon)   105273  1487329200  MAGICuenca91  442761
# 2        Castel Beer (Gabon)   105273  1466762400        Sibarh  288889
# 3        Castel Beer (Gabon)   105273  1451646000       fombe89  250510
# 4        Castel Beer (Gabon)   105273  1445594400    kevnic2008  122778
# ...                      ...      ...         ...           ...     ...
# 7123801         Svejk Blonde   220897  1411034400        Travlr   83882
# 7123802         Svejk Blonde   220897  1385895600         TBone   10233
# 7123803           Svejk Dark   220898  1415098800      Rob_D_UK  257161
# 7123804           Svejk Dark   220898  1410861600        Travlr   83882
# 7123805           Svejk Dark   220898  1385895600         TBone   10233
#
#          overall                                               text  \
# 0              8  Puszka 0,33l dzięki Christoph . Kolor jasnozło...
# 1              8  Cerveza pale lager gabonesa. MÃ¡s floja que la...
# 2              5  Kolor- złoty, klarowny. Piana - drobna, średni...
# 3              5  Botella, de GabÃ³n regalo familiar.31/01/2015C...
# 4              7  Many thanks for this beer to Erzengel. Pours l...
# ...          ...                                                ...
# 7123801       10  Draft at the source. Clear golden color, fluff...
# 7123802       10  Tap @brewpub, TiraneClear golden color, good c...
# 7123803        9  In their beer garden after a walking tour arou...
# 7123804        6  Draft at the source. Hazy maroon color, tan he...
# 7123805        8  Tap @brewpub, TiraneDark brown color, nice cre...
#
#          text_length  relative_time         review_time  \
# 0                 18              0 2016-04-26 12:00:00
# 1                 66      242010000 2017-02-17 12:00:00
# 2                 23      221443200 2016-06-24 12:00:00
# 3                 16      206326800 2016-01-01 12:00:00
# 4                 22      200275200 2015-10-23 12:00:00
# ...              ...            ...                 ...
# 7123801           26       25138800 2014-09-18 12:00:00
# 7123802           31              0 2013-12-01 12:00:00
# 7123803           27       29203200 2014-11-04 12:00:00
# 7123804           24       24966000 2014-09-16 12:00:00
# 7123805           41              0 2013-12-01 12:00:00
#
#                               location
# 0                               Poland
# 1                                Spain
# 2                               Poland
# 3                                Spain
# 4                              Germany
# ...                                ...
# 7123801  United States, North Carolina
# 7123802                        Finland
# 7123803                          Spain
# 7123804  United States, North Carolina
# 7123805                        Finland
#
# [7123806 rows x 11 columns]

# %%
beer_to_brew_rb = beer_rb[['beer_id', 'brewery_id']].set_index(keys='beer_id')['brewery_id']
beer_to_brew_rb = beer_to_brew_rb.apply(str)

# %%
brew_locations = breweries[['id', 'location']].set_index(keys='id')['location']

# %%
brew_rb['id'] = brew_rb['id'].apply(str)
brew_rb = brew_rb[['id', 'location']].set_index(keys='id')['location']
def beer_country_rb(identifier):
    brewery = beer_to_brew_rb.loc[identifier]
    return brew_rb.loc[brewery]

# %%
ratings_rb['beer_location'] = ratings_rb['beer_id'].apply(beer_country_rb)

# %%
ratings_rb
# Out:
#                    beer_name  beer_id        date     user_name user_id  \
# 0          33 Export (Gabon)   410549  1461664800       Manslow  175852
# 1        Castel Beer (Gabon)   105273  1487329200  MAGICuenca91  442761
# 2        Castel Beer (Gabon)   105273  1466762400        Sibarh  288889
# 3        Castel Beer (Gabon)   105273  1451646000       fombe89  250510
# 4        Castel Beer (Gabon)   105273  1445594400    kevnic2008  122778
# ...                      ...      ...         ...           ...     ...
# 7123801         Svejk Blonde   220897  1411034400        Travlr   83882
# 7123802         Svejk Blonde   220897  1385895600         TBone   10233
# 7123803           Svejk Dark   220898  1415098800      Rob_D_UK  257161
# 7123804           Svejk Dark   220898  1410861600        Travlr   83882
# 7123805           Svejk Dark   220898  1385895600         TBone   10233
#
#          overall                                               text  \
# 0              8  Puszka 0,33l dzięki Christoph . Kolor jasnozło...
# 1              8  Cerveza pale lager gabonesa. MÃ¡s floja que la...
# 2              5  Kolor- złoty, klarowny. Piana - drobna, średni...
# 3              5  Botella, de GabÃ³n regalo familiar.31/01/2015C...
# 4              7  Many thanks for this beer to Erzengel. Pours l...
# ...          ...                                                ...
# 7123801       10  Draft at the source. Clear golden color, fluff...
# 7123802       10  Tap @brewpub, TiraneClear golden color, good c...
# 7123803        9  In their beer garden after a walking tour arou...
# 7123804        6  Draft at the source. Hazy maroon color, tan he...
# 7123805        8  Tap @brewpub, TiraneDark brown color, nice cre...
#
#          text_length  relative_time         review_time  \
# 0                 18              0 2016-04-26 12:00:00
# 1                 66      242010000 2017-02-17 12:00:00
# 2                 23      221443200 2016-06-24 12:00:00
# 3                 16      206326800 2016-01-01 12:00:00
# 4                 22      200275200 2015-10-23 12:00:00
# ...              ...            ...                 ...
# 7123801           26       25138800 2014-09-18 12:00:00
# 7123802           31              0 2013-12-01 12:00:00
# 7123803           27       29203200 2014-11-04 12:00:00
# 7123804           24       24966000 2014-09-16 12:00:00
# 7123805           41              0 2013-12-01 12:00:00
#
#                               location beer_location
# 0                               Poland         Gabon
# 1                                Spain         Gabon
# 2                               Poland         Gabon
# 3                                Spain         Gabon
# 4                              Germany         Gabon
# ...                                ...           ...
# 7123801  United States, North Carolina       Albania
# 7123802                        Finland       Albania
# 7123803                          Spain       Albania
# 7123804  United States, North Carolina       Albania
# 7123805                        Finland       Albania
#
# [7123806 rows x 12 columns]
